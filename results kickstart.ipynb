# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
# Reads results csv files into df
def read_csv(path):
    csv_files = glob.glob(path + "/*.csv")
    df_list = (pd.read_csv(file) for file in csv_files)
    full_df = pd.concat(df_list, ignore_index=True)
    full_df.columns = [c.replace(' ', '_') for c in full_df.columns]
    return full_df

# %%
path_1 = 'results/kickstart/1/loss_1.csv'
path_2 = 'results/kickstart/2/loss_1.csv'
path_3 = 'results/kickstart/3/loss_1.csv'
path_4 = 'results/kickstart/4/loss_1.csv'

# %%
pd.read_csv(path_4).plot()
# Out:
# <Axes: >

# %%
loss = 0
for i in range(50):
    loss = + 50

# %%
loss
# Out:
# 50
